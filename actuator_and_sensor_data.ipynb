# %% [markdown]
# # Passive control systems
#
# ## 1. **Passive magnetic altitude control (PMAC)**
# ### Sensor
# | Sensor | image | cost range | Reason/use |
# |-------|------|------|------|
# |  Magnetometer     | rrr      | rrrr     | Is used to measure the magnetic field and help the sat cube determine their orientation.|
# | Sun sensors| | | Its used to identify the direction of the sun, which helps with the altitude determination/control|
# ### Actuators
# | Actuators  | image | cost range | reason/use |
# |-------|------|------|------|
# |  Permanent magnets (bar magnets )     | rrr      | rrrr     | They are used as a way to restore torque to align the cubesat with the earths magnetic field.|
# |Hysteresis rods/strips| | | They are a soft magnetic piece that is able to dissipate rotational energy as heat, efectively stoping tumbling.|
#
# ## 2. **Gravity gradient stabilization system**
# ### Sensor
# | Sensor | image | cost range | Reason/use |
# |-------|------|------|------|
# |Magnetometer|||Measures the earth magnetic field and helps determine the orientation, and activate magnetorques.|
# |Sun sensors|||Helps determine the suns direction in relation to the body |
# |Earth horizon sensor|| |Helps find the vector that points towards the earth which helps with gravity gradient calculations|
# |Gyroscopes| || Helps measure angular velocity |
#
# ### Actuators
# | Actuators  | image | cost range | reason/use |
# |-------|------|------|------|
# |Gravity gradient booms| | |an extendeble boom that increases moment of inertia, which creates torque|
# |Hysteria rods| | | Used to damp out oscilations by absorving energy.|
# |Permanent magnets(bar magnets)| | |allows alighnment with the earths magnetic fields.|
# |Magnetorquers| | |Helps the system to control the tumbling of the satelite.|
#
# ## 3. **Aerodynamic stabilization (Drag gradient)**
# ### Sensor
# | Sensor | image | cost range | Reason/use |
# |-------|------|------|------|
# |Magnetometer| | | Measure the earths magnetic field to determine altitude|
# |Sun sensors| | |They determine the sun direction and helps for altitude referencing.|
# | Nadir sensor (horizon sensor)| || Help detect the earths limb to make sure the drag surface is pointed correctly|
#
# ### Actuators
# | Actuators  | image | cost range | reason/use |
# |-------|------|------|------|
# | Deployable booms| | |Booms and or pannels that extend to change the center of presure and center of mass to provide stabilization.|
# |Drag deorbit| | | they are retractble pannels that allow for calculated drag.|
# |Magnetic torque| | |They help stable the orientation and damp oscillations of the satcube.|
# |Stepper motors| | | They change the lenght of the drag surfaces.
# ## 4. **Spin stabilization**
# ### Sensor
# | Sensor | image | cost range | Reason/use |
# |-------|------|------|------|
# |Magnetometer| | |Used to measure the earths magnetic field vector to align the satelite.|
# |Sun sensors| | | To determine the suns position in relation to the satcube.|
# |IMU (inertial measurement unit) or gyroscope| | | Use to measure things like angular velocity and other values for the control system |
#
# ### Actuators
# | Actuators  | image | cost range | reason/use |
# |-------|------|------|------|
# |Permanent magnets || | Used to align sat cuve with the earths magnetic field lines|
# |hysteresis rods| | |Absorving energy from rotational motion to reduce tumbling|
#
# ## 5. **Solar radiation pressure control (super hard)**
# ### Sensor
# | Sensor | image | cost range | Reason/use |
# |-------|------|------|------|
# |Sun sensors| | |Helps know the orientation of the body relative to the sun.|
# |magnetometer| | | Helps gather more information of the magnetic fields around the sat cube.|
# |Earth Horizon sensor| | | An horizon sensor to determine the horizon sensor.
# ### Actuators
# | Actuators  | image | cost range | reason/use |
# |-------|------|------|------|
# |deployable reflective surface| | |They allow low small modulation to create low torque.|
# |Reflectivity control devices| | |Pannels that can switch from mirror like to diffusion mirrior to change modulation of torque.|
# |Varriable relfectivity surfaces|  | |Small flaps that can change the surface properties that create reflection and absorption to create torque changes, and variations.|
# |Offset center of pressure mass| | |The structure is suposed to be influenced by solar radiation offset from center of mass that can create natural and passive torque.|

# %% [markdown]
# # Active systems
# ## 1. Magnetic actuation systems
# ## Actuators
# | Actuators | image | cost range | Reason/use |
# |-------|------|------|------|
# |Magnetorquer rods| | | They are conductive rods of wire that create high torque|
# |Air coils| | |Made of self bonding wire that create lower torque|
# | printed circuit board PCB coils/torquers| | | They are small coils in the PCBs that are integrated in the PCB and can create torque via suplying energy to create a small magnetic torque.|
# |Electromagnets| | | with the general idea of creating torque for active movement.|
# ## Sensors
# | Sensor | image | cost range | Reason/use |
# |-------|------|------|------|
# |Magnetometer| | | Primery sensor that can measure the magnetic field to calculate the nesesary magnetic inputs to create the desired torque to x or y direction.|
# | Gyroscopes | | | Used to measure angular velocity which is esential for reducing the rotation rate.|
# |sun sensors| | | used for orientation data|
# | horizon sensors| | | Used for locating earths horazon for calculations relative to earth.|
# |GPS receiver| | | used to determine orbital posicion and velocity|
# ## 2. Kinetic actuation systems
# ## Actuators
# | Actuators | image | cost range | Reason/use |
# |-------|------|------|------|
# |Reaction wheels|  | | Primary actuator for 3 axis altitude control while conserving angular momentum for torque creation.|
# |magnetorquers| | | To create magnetic moments and move the satcube|
# |propulsion systems||| cold gas or mass ejecting wheels for small orbital corrections and/or small altitude ajustments.|
# |Moving mass actuators|  | | Moving mass actuators are a specialized form of kinetic actuation by shifting internal mass and control altitude.|
# ## Sensors
# | Sensor | image | cost range | Reason/use |
# |-------|------|------|------|
# | magnetometers| | |to determine orientation relative to earths magnetic field|
# |Sun sensors | | | Help detect the suns direction for further orientation calculations|
# | Gyroscopes| | | Help measure angular velocity for rate sensing.|
# |Star tracker (we are developing it)| | | helps provides high altitude determination via calculating star fields and using them as information of its current orientation.|
# |GPS reciver| | | used to determine their current orbital posicion and velocity.|
# ## 3. Propulsion systems
# ## Actuators
# | Actuators | image | cost range | Reason/use |
# |-------|------|------|------|
# |thrusters (cold gas, electrospray,micro cathode arc, pulsated plasma, half effect/ion)| | | They use their respective fuel for propulsion, some are using mass propulsion while others use volatage and or energy as their "fuel" like for example arc thrusters|
# |Magnetorques| | | Coils that are used for altitude control|
# ## Sensors
# | Sensor | image | cost range | Reason/use |
# |-------|------|------|------|
# | magnetometers| | |to determine orientation relative to earths magnetic field|
# |Sun sensors | | | Help detect the suns direction for further orientation calculations|
# | Gyroscopes| | | Help measure angular velocity for rate sensing.|
# |Star tracker (we are developing it)| | | helps provides high altitude determination via calculating star fields and using them as information of its current orientation.|
# |GPS reciver| | | used to determine their current orbital posicion and velocity.|
# |temperature sensors| | | used to monitur thruster and propelent health|
# | pressure transducers| | | they are a vital part to monitor the propelant tank pressure and consumption|
